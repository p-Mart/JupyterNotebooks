# %% [markdown]
# ### Using numpy and matplotlib to plot the function:
# ### $$ e^x, x  \in [0, 10] $$

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display, Math, Latex

X = np.linspace(0,10)
Y = np.exp(X)

plt.plot(X,Y)
plt.show()
